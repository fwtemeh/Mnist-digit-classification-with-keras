# %% [markdown]
# #Project classification

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ###Definition

# %%
(X_train,y_train),(X_test,y_test)=keras.datasets.mnist.load_data()

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (60000, 28, 28)
# (60000,)
# (10000, 28, 28)
# (10000,)

# %%
plt.imshow(X_train[115])

# %% [markdown]
# ###Normalization

# %%
X_train,X_test=X_train/255,X_test/255

#  چرا توی نرمال سازی فقط ضریب های x را نرمال میکنیم ؟
# X_train,X_test=X_train/255,x_test/255
# چون در MNIST:
# X → ویژگی‌ها (features) یعنی خود پیکسل‌های تصویر هستند (عدد شدت روشنایی 0 تا 255)
# y → برچسب (label) یعنی عدد 0 تا 9 است

# %% [markdown]
# ###Model

# %%
len(np.unique(y_train))
# مشاهده تعداد خروجی در مدل طبقه بندی و قرار دادن ان در تعداد نورون خروجی در لایه اخر
# Out:
# 10

# %%
model = keras.models.Sequential(
    [
    keras.layers.Flatten(input_shape=[28,28]),
    keras.layers.Dense(10,activation="selu"),
    keras.layers.Dense(10,activation="softmax"),
    ]
 )
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_5 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 10)             │         7,850 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 10)             │           110 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,960 (31.09 KB)
#  Trainable params: 7,960 (31.09 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
weight,bias= model.layers[2].get_weights()
print(weight.shape)
print(bias.shape)
# Out:
# (10, 10)
# (10,)

# %% [markdown]
# ###compile

# %%
model.compile(
        loss="sparse_categorical_crossentropy",
        optimizer="adam",
        metrics=["accuracy"]
        )

# %% [markdown]
# ####EarlyStopping

# %%
early_stop = EarlyStopping(
    monitor="val_loss",
    patience=3,
    restore_best_weights=True
)

# %%
history1 = model.fit(
    X_train,
    y_train,
    epochs=30,
    batch_size=24,
    validation_split=0.2,
    callbacks=[early_stop]

)
# Out:
# Epoch 1/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8700 - loss: 0.4748 - val_accuracy: 0.9175 - val_loss: 0.2964
# Epoch 2/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9159 - loss: 0.2958 - val_accuracy: 0.9197 - val_loss: 0.2791
# Epoch 3/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9229 - loss: 0.2726 - val_accuracy: 0.9287 - val_loss: 0.2530
# Epoch 4/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9258 - loss: 0.2594 - val_accuracy: 0.9289 - val_loss: 0.2566
# Epoch 5/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9294 - loss: 0.2484 - val_accuracy: 0.9325 - val_loss: 0.2452
# Epoch 6/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9319 - loss: 0.2393 - val_accuracy: 0.9326 - val_loss: 0.2422
# Epoch 7/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9339 - loss: 0.2324 - val_accuracy: 0.9308 - val_loss: 0.2409
# Epoch 8/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9370 - loss: 0.2251 - val_accuracy: 0.9351 - val_loss: 0.2320
# Epoch 9/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9380 - loss: 0.2202 - val_accuracy: 0.9329 - val_loss: 0.2362
# Epoch 10/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9387 - loss: 0.2156 - val_accuracy: 0.9347 - val_loss: 0.2324
# Epoch 11/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9403 - loss: 0.2111 - val_accuracy: 0.9339 - val_loss: 0.2318
# Epoch 12/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9417 - loss: 0.2062 - val_accuracy: 0.9356 - val_loss: 0.2265
# Epoch 13/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9419 - loss: 0.2033 - val_accuracy: 0.9346 - val_loss: 0.2320
# Epoch 14/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9431 - loss: 0.1994 - val_accuracy: 0.9348 - val_loss: 0.2294
# Epoch 15/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9439 - loss: 0.1963 - val_accuracy: 0.9347 - val_loss: 0.2247
# Epoch 16/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9444 - loss: 0.1941 - val_accuracy: 0.9369 - val_loss: 0.2237
# Epoch 17/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9444 - loss: 0.1907 - val_accuracy: 0.9339 - val_loss: 0.2264
# Epoch 18/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9452 - loss: 0.1876 - val_accuracy: 0.9362 - val_loss: 0.2195
# Epoch 19/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9457 - loss: 0.1853 - val_accuracy: 0.9371 - val_loss: 0.2239
# Epoch 20/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9461 - loss: 0.1830 - val_accuracy: 0.9373 - val_loss: 0.2179
# Epoch 21/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9468 - loss: 0.1798 - val_accuracy: 0.9357 - val_loss: 0.2186
# Epoch 22/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9478 - loss: 0.1772 - val_accuracy: 0.9367 - val_loss: 0.2191
# Epoch 23/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9485 - loss: 0.1755 - val_accuracy: 0.9371 - val_loss: 0.2155
# Epoch 24/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9490 - loss: 0.1724 - val_accuracy: 0.9383 - val_loss: 0.2130
# Epoch 25/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9498 - loss: 0.1716 - val_accuracy: 0.9380 - val_loss: 0.2147
# Epoch 26/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9499 - loss: 0.1688 - val_accuracy: 0.9403 - val_loss: 0.2101
# Epoch 27/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9503 - loss: 0.1678 - val_accuracy: 0.9394 - val_loss: 0.2152
# Epoch 28/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9511 - loss: 0.1651 - val_accuracy: 0.9403 - val_loss: 0.2077
# Epoch 29/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9521 - loss: 0.1635 - val_accuracy: 0.9390 - val_loss: 0.2152
# Epoch 30/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9525 - loss: 0.1619 - val_accuracy: 0.9418 - val_loss: 0.2108

# %% [markdown]
# ### testModel

# %%
model.evaluate(X_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9416 - loss: 0.2063
# [0.20634013414382935, 0.9416000247001648]

# %%
pred = model.predict(X_test[100:200])
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step

# %%
np.argmax(pred, axis=1)
# Out:
# array([6, 0, 5, 4, 9, 9, 2, 1, 9, 4, 8, 7, 3, 9, 7, 4, 4, 4, 9, 9, 5, 4,
#        7, 6, 4, 9, 0, 5, 8, 5, 6, 6, 5, 7, 8, 1, 0, 1, 6, 4, 6, 7, 3, 1,
#        7, 1, 8, 2, 0, 4, 9, 9, 5, 5, 1, 5, 6, 0, 3, 4, 4, 6, 5, 4, 6, 5,
#        4, 5, 1, 4, 4, 7, 2, 3, 2, 7, 1, 8, 1, 8, 1, 8, 5, 0, 8, 9, 2, 5,
#        0, 1, 1, 1, 0, 9, 0, 3, 1, 6, 4, 2])

# %%
plt.figure(figsize=(10,10))

for i in range(100):
    plt.subplot(10,10,i+1)
    plt.imshow(X_test[100+i])
    plt.title(f"Pred:{np.argmax(pred[i])}")
    plt.axis("off")

plt.show()
